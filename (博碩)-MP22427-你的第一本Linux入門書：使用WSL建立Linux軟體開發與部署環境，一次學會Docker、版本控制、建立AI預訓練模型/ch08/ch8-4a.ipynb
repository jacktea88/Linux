# %%
from keras_nlp.models import GPT2CausalLMPreprocessor
from keras_nlp.models import GPT2CausalLM
import gradio as gr
import keras

keras.mixed_precision.set_global_policy("mixed_float16")
# 建立 GPT2CausalLMPreprocessor 預處理物件
preprocessor = GPT2CausalLMPreprocessor.from_preset(
    "gpt2_base_en",
    sequence_length=128,
)
# 建立 GPT-2 模型
gpt2_lm = GPT2CausalLM.from_preset(
    "gpt2_base_en",
    preprocessor=preprocessor
)

def predict(input):
    # 使用模型進行預測
    output = gpt2_lm.generate(input, 
                              max_length=200)
    return output

examples = ["My trip to New York was", 
            "My trip to Taipei was"]
app = gr.Interface(fn=predict, 
                   inputs="text", 
                   outputs="text",
                   examples=examples)
app.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7871
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7871/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
